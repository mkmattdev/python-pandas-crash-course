# %% [markdown]
# # 00. Sprawdzenie środowiska
#
# Ten notebook uruchom **przed zajęciami**. Jeśli wszystkie komórki przejdą bez błędu,
# masz wszystko, czego potrzebujemy.
#
# **Jak uruchomić komórkę:** kliknij w nią i naciśnij `Shift + Enter`.
# Wynik pojawia się pod komórką.

# %%
# Sprawdzamy, czy biblioteki (gotowe dodatki do Pythona) są zainstalowane.
import sys            # informacje o samym Pythonie
import pandas as pd   # pandas = biblioteka do pracy z tabelami; skrót "pd" to przyjęty zwyczaj
import openpyxl       # dzięki niej pandas czyta i zapisuje pliki Excela
import matplotlib     # rysowanie wykresów

print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)
print("openpyxl:", openpyxl.__version__)
print("matplotlib:", matplotlib.__version__)

# %%
# Wczytujemy plik z danymi ćwiczeniowymi i pokazujemy pierwsze 5 wierszy.
df = pd.read_excel("data/przetargi_2019_2024.xlsx")   # df = skrót od DataFrame, czyli "tabela"
print("Liczba wierszy:", len(df))
df.head()

# %% [markdown]
# Jeśli nad tym tekstem widzisz tabelę z przetargami: ✅ środowisko gotowe. Do zobaczenia na zajęciach!
